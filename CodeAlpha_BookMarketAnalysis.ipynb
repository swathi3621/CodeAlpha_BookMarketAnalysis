# %% [markdown]
# # CodeAlpha - Book Market Analysis
# ## Web Scraping + EDA + Data Visualization

# %% [markdown]
# ### Task 1: Web Scraping
# Run the scraper to collect the dataset from Books to Scrape.

# %%
# %run ../scraper.py

# %% [markdown]
# ### Task 2 & 3: EDA and Data Visualization

# %%
# %run ../eda_visualization.py
